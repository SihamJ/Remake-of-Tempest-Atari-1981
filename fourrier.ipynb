# %%
import matplotlib.pyplot as plt
from scipy.io import wavfile as wav
from scipy.fftpack import fft
import numpy as np
rate, data = wav.read('Audio/gameover.wav')
fft_out = fft(data)

a_file = open("Audio/gameover.txt", "w")

fft_out = fft_out.real
size = fft_out.shape[0] * fft_out.shape[1]
array = np.reshape(fft_out, (size,1))

for row in (array):
    np.savetxt(a_file, row)
    a_file.write(",")

a_file.close()

# %matplotlib inline
plt.plot(fft_out)
plt.show()
# Out:
# /tmp/ipykernel_78516/421760639.py:5: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   rate, data = wav.read('Audio/gameover.wav')
