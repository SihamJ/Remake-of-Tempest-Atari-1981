# %%
import matplotlib.pyplot as plt
from scipy.io import wavfile as wav
from scipy.fftpack import fft
import numpy as np
rate, data = wav.read('Audio/shoot.wav')
fft_out = fft(data)

a_file = open("Audio/txt/shoot.txt", "w")

fft_out = fft_out.real
size = fft_out.shape[0] * fft_out.shape[1]
array = np.reshape(fft_out, (size,1))


print(len(array)) 

for row in (array):
    np.savetxt(a_file, row)
    a_file.write(",")

a_file.close()

# %matplotlib inline
plt.plot(fft_out)
plt.show()
# Out:
# 165888
